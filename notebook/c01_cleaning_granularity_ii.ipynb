# %% [markdown]
# ## Questão de Negócio
#
# A empresa Star Jeans! Eduardo e Marcelo são dois brasileiros, amigos e sócios de empreendi-
# mento. Depois de vários negócio bem sucedidos, eles estão planejando entrar no mercado de moda
# dos USA como um modelo de negócio do tipo E-commerce.
# A idéia inicial é entrar no mercado com apenas um produto e para um público específico, no caso
# o produto seria calças Jenas para o público masculino. O objetivo é manter o custo de operação
# baixo e escalar a medida que forem conseguindo clientes.
# Porém, mesmo com o produto de entrada e a audiência definidos, os dois sócios não tem experiência
# nesse mercado de moda e portanto não sabem definir coisas básicas como preço, o tipo de calça e
# o material para a fabricação de cada peça.
# Assim, os dois sócios contrataram uma consultoria de Ciência de Dados para responder as seguintes
# perguntas:
#
# 1. Qual o melhor preço de venda para as calças?
#
# 2. Quantos tipos de calças e suas
# cores para o produto inicial?
#
# 3. Quais as matérias-prima necessárias para confeccionar as calças?
#
# Obs.: As principais concorrentes da empresa Start Jeans são as americadas H&M e Macys.

# %% [markdown]
# # Limpeza e definição da granularidade

# %% [markdown]
# # Import Librarys

# %%
import re #regex Library
import warnings
import inflection

import numpy             as np
import pandas            as pd
import seaborn           as sns
import matplotlib.pyplot as plt

from IPython.display       import Image
from IPython.core.display  import HTML


warnings.filterwarnings( 'ignore' )

# %% [markdown]
# ## Help Function

# %%
def jupyter_settings():
    #%matplotlib notebook
    #%pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()
    
jupyter_settings()
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('../data/data_raw_size_all.csv')

# %%
df.sample()
# Out:
#       Unnamed: 0  product_id product_category        product_name product_price      scrapy_datetime  style_id  color_id        color_name       fit             composition                                            size
# 3399        3399   938875012   men_jeans_slim  Slim Tapered Jeans       $ 39.99  2022-04-19 13:17:23    938875        12  Light denim blue  Slim fit  Cotton 99%, Spandex 1%  The model is 187cm/6'2" and wears a size 31/32

# %% [markdown]
# # Rename columns

# %%
data = df.copy()

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'product_id', 'product_category', 'product_name',
#        'product_price', 'scrapy_datetime', 'style_id', 'color_id',
#        'color_name', 'fit', 'composition', 'size'],
#       dtype='object')

# %% [markdown]
# # Clean to dataframe

# %%
#data.shape
data.dtypes
# Out:
# Unnamed: 0           int64
# product_id           int64
# product_category    object
# product_name        object
# product_price       object
# scrapy_datetime     object
# style_id             int64
# color_id             int64
# color_name          object
# fit                 object
# composition         object
# size                object
# dtype: object

# %%
data.isna().sum()
# Out:
# Unnamed: 0             0
# product_id             0
# product_category       0
# product_name           0
# product_price          0
# scrapy_datetime        0
# style_id               0
# color_id               0
# color_name             1
# fit                 1034
# composition         1034
# size                1034
# dtype: int64

# %%
data = data.drop( columns=['Unnamed: 0'], axis=1 )

# %%
#df.isna().sum()
data.shape
# Out:
# (5610, 11)

# %%
# product id
data = data.dropna( subset=['product_id'] )
data['product_id'] = data['product_id'].astype( int )

# product name
data['product_name'] = data['product_name'].apply( lambda x: x.replace( ' ', '_' ).lower())

# product price
data['product_price'] = data['product_price'].apply(lambda x: x.replace( '$ ', '' )).astype(float)

# scrapy datetime
data['scrapy_datetime'] = pd.to_datetime(data['scrapy_datetime'],format='%Y-%m-%d %H:%M:%S' )

# style id
data['style_id'] = data['style_id'].astype( int )

# color id
data['color_id'] = data['color_id'].astype( int )

#color name
data['color_name'] = data['color_name'].apply( lambda x: x.replace(' ', '_' ).replace( '/', '_' ).lower() if pd.notnull( x ) else x )

# fit
data['fit'] = data['fit'].apply( lambda x: x.replace( ' ', '_' ).lower() if pd.notnull( x ) else x )
# quando houver valores nulos, acrescentar o notnull...

# %%
# size number
#data['size_number'] = data['size'].apply( lambda x: re.search('(\d{3}cm)', x ).group(0) if pd.notnull( x ) else x)
#data['size_number'] = data['size_number'].apply( lambda x: re.search( '(\d{3})', x).group(0) if pd.notnull( x ) else x ).astype(float)

data['size_number'] = data['size'].str.extract( '(\d{3}cm)')
data['size_number'] = data['size_number'].apply( lambda x: re.search( '(\d{3})', x).group(0) if pd.notnull( x ) else x ).astype(float)
#
### size model
### size model
data['size_model'] = data['size'].str.extract( '(size\s\d+.\d+|size\s\w+)')
#
#### Droping  columns
data = data.drop( columns=['size'], axis=1 )

# %%
##composition
# droping lines with pocket and lining materials
data = data[~data['composition'].str.contains( 'Pocket lining:', na=False )]
data = data[~data['composition'].str.contains( 'Pocket:', na=False )]
data = data[~data['composition'].str.contains( 'Lining:', na=False )]
data = data[~data['composition'].str.contains( 'Shell:', na=False )]
data = data[~data['composition'].str.contains( '"FOR CHILD’S SAFETY, GARMENT SHOULD FIT SNUGLY. THIS GARMENT IS NOT FLAME RESISTANT. LOOSE-FITTING GARMENT IS MORE LIKELY TO CATCH FIRE."', na=False )]


#Drop duplicat
data = data.drop_duplicates(subset=['product_id', 'product_category', 'product_name', 'product_price',
                                    'scrapy_datetime', 'style_id', 'color_id', 'color_name', 'fit'])
#data = data.drop_duplicates()

# reste index
data = data.reset_index( drop=True )

# break composition by comma
df1 = data['composition'].str.split( ',', expand=True )
##
### cotton | spandex | polyester
df_ref = pd.DataFrame( index=np.arange( len( data ) ), columns=['cotton', 'spandex', 'polyester'] )
##
### cotton
df_cotton = df1[0]
df_cotton.name = 'cotton'
df_ref = pd.concat( [df_ref, df_cotton ], axis=1 )
df_ref = df_ref.iloc[:, ~df_ref.columns.duplicated( keep='last')]
df_ref['cotton'] = df_ref['cotton'].fillna('Cotton 0%')
###
#### spandex
df_spandex = df1.loc[df1[1].str.contains( 'Spandex', na=True ), 1]
df_spandex.name = 'spandex'
df_ref = pd.concat( [df_ref, df_spandex], axis=1 )
df_ref = df_ref.iloc[:, ~df_ref.columns.duplicated( keep='last') ]
df_ref['spandex'] = df_ref['spandex'].fillna('Spandex 0%')
##
### polyester
df_polyester = df1.loc[df1[1].str.contains( 'Polyester', na=True ), 1]
df_polyester.name = 'polyester'
df_ref = pd.concat( [df_ref, df_polyester], axis=1 )
df_ref = df_ref.iloc[:, ~df_ref.columns.duplicated( keep='last') ]
df_ref['polyester'] = df_ref['polyester'].fillna('Polyester 0%')

# %%
# final join
data = pd.concat( [data, df_ref], axis=1 )
data.head()
# Out:
#    product_id product_category product_name  product_price     scrapy_datetime  style_id  color_id        color_name  fit composition  size_number size_model     cotton     spandex     polyester     cotton     spandex     polyester     cotton     spandex     polyester
# 0  1024256001   men_jeans_slim   slim_jeans          19.99 2022-04-19 13:17:23   1024256         1        denim_blue  NaN         NaN          NaN        NaN  Cotton 0%  Spandex 0%  Polyester 0%  Cotton 0%  Spandex 0%  Polyester 0%  Cotton 0%  Spandex 0%  Polyester 0%
# 1  1024256001   men_jeans_slim   slim_jeans          19.99 2022-04-19 13:17:23   1024256         1             black  NaN         NaN          NaN        NaN  Cotton 0%  Spandex 0%  Polyester 0%  Cotton 0%  Spandex 0%  Polyester 0%  Cotton 0%  Spandex 0%  Polyester 0%
# 2  1024256001   men_jeans_slim   slim_jeans          19.99 2022-04-19 13:17:23   1024256         1  light_denim_blue  NaN         NaN          NaN        NaN  Cotton 0%  Spandex 0%  Polyester 0%  Cotton 0%  Spandex 0%  Polyester 0%  Cotton 0%  Spandex 0%  Polyester 0%
# 3  1024256001   men_jeans_slim   slim_jeans          19.99 2022-04-19 13:17:23   1024256         1         dark_blue  NaN         NaN          NaN        NaN  Cotton 0%  Spandex 0%  Polyester 0%  Cotton 0%  Spandex 0%  Polyester 0%  Cotton 0%  Spandex 0%  Polyester 0%
# 4  1024256001   men_jeans_slim   slim_jeans          19.99 2022-04-19 13:17:23   1024256         1   dark_denim_blue  NaN         NaN          NaN        NaN  Cotton 0%  Spandex 0%  Polyester 0%  Cotton 0%  Spandex 0%  Polyester 0%  Cotton 0%  Spandex 0%  Polyester 0%

# %%
data.head(100)
# Out:
#     product_id   product_category        product_name  product_price     scrapy_datetime  style_id  color_id                color_name         fit             composition  size_number  size_model      cotton      spandex     polyester      cotton      spandex     polyester      cotton      spandex     polyester
# 0   1024256001     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         1                denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 1   1024256001     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         1                     black         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 2   1024256001     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         1          light_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 3   1024256001     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         1                 dark_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 4   1024256001     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         1           dark_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 5   1024256001     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         1                 dark_gray         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 6   1024256001     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         1                     white         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 7   1024256002     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         2                denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 8   1024256002     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         2                     black         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 9   1024256002     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         2          light_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 10  1024256002     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         2                 dark_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 11  1024256002     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         2           dark_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 12  1024256002     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         2                 dark_gray         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 13  1024256002     men_jeans_slim          slim_jeans          19.99 2022-04-19 13:17:23   1024256         2                     white         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 14   811993036  men_jeans_regular       regular_jeans          29.99 2022-04-19 13:17:23    811993        36          black_washed_out         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 15   811993036  men_jeans_regular       regular_jeans          29.99 2022-04-19 13:17:23    811993        36             graphite_gray         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 16   811993036  men_jeans_regular       regular_jeans          29.99 2022-04-19 13:17:23    811993        36          light_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 17   811993036  men_jeans_regular       regular_jeans          29.99 2022-04-19 13:17:23    811993        36                     cream         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 18   811993036  men_jeans_regular       regular_jeans          29.99 2022-04-19 13:17:23    811993        36                light_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 19   811993036  men_jeans_regular       regular_jeans          29.99 2022-04-19 13:17:23    811993        36                denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 20   811993036  men_jeans_regular       regular_jeans          29.99 2022-04-19 13:17:23    811993        36           dark_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 21   811993036  men_jeans_regular       regular_jeans          29.99 2022-04-19 13:17:23    811993        36           pale_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 22   811993036  men_jeans_regular       regular_jeans          29.99 2022-04-19 13:17:23    811993        36                      blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 23   811993036  men_jeans_regular       regular_jeans          29.99 2022-04-19 13:17:23    811993        36                 dark_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 24   811993036  men_jeans_regular       regular_jeans          29.99 2022-04-19 13:17:23    811993        36                     black         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 25   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2                light_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 26   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2          light_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 27   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2                     white         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 28   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2                 dark_gray         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 29   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2                denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 30   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2           pale_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 31   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2                     black         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 32   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2          light_denim_blue    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 33   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2                     white    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 34   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2                 dark_gray    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 35   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2                light_blue    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 36   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2                denim_blue    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 37   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2           pale_denim_blue    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 38   938875002     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875         2                     black    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 39  1008549004  men_jeans_regular       regular_jeans          24.99 2022-04-19 13:17:23   1008549         4          light_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 40  1008549004  men_jeans_regular       regular_jeans          24.99 2022-04-19 13:17:23   1008549         4                denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 41  1008549004  men_jeans_regular       regular_jeans          24.99 2022-04-19 13:17:23   1008549         4                 dark_gray         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 42  1008549004  men_jeans_regular       regular_jeans          24.99 2022-04-19 13:17:23   1008549         4                 dark_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 43  1008549004  men_jeans_regular       regular_jeans          24.99 2022-04-19 13:17:23   1008549         4                     black         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 44  1008549004  men_jeans_regular       regular_jeans          24.99 2022-04-19 13:17:23   1008549         4                light_gray         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 45   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13                light_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 46   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13          light_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 47   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13                     white         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 48   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13                 dark_gray         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 49   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13                denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 50   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13           pale_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 51   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13                     black         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 52   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13          light_denim_blue    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 53   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13                     white    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 54   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13                 dark_gray    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 55   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13                light_blue    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 56   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13                denim_blue    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 57   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13           pale_denim_blue    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 58   938875013     men_jeans_slim  slim_tapered_jeans          39.99 2022-04-19 13:17:23    938875        13                     black    slim_fit  Cotton 99%, Spandex 1%        187.0  size 31/32  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%  Cotton 99%   Spandex 1%  Polyester 0%
# 59  1008549007  men_jeans_regular       regular_jeans          24.99 2022-04-19 13:17:23   1008549         7          light_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 60  1008549007  men_jeans_regular       regular_jeans          24.99 2022-04-19 13:17:23   1008549         7                denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 61  1008549007  men_jeans_regular       regular_jeans          24.99 2022-04-19 13:17:23   1008549         7                 dark_gray         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 62  1008549007  men_jeans_regular       regular_jeans          24.99 2022-04-19 13:17:23   1008549         7                 dark_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 63  1008549007  men_jeans_regular       regular_jeans          24.99 2022-04-19 13:17:23   1008549         7                     black         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 64  1008549007  men_jeans_regular       regular_jeans          24.99 2022-04-19 13:17:23   1008549         7                light_gray         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 65   979945009    men_jeans_loose         loose_jeans          39.99 2022-04-19 13:17:23    979945         9                     black         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 66   979945009    men_jeans_loose         loose_jeans          39.99 2022-04-19 13:17:23    979945         9          light_denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 67   979945009    men_jeans_loose         loose_jeans          39.99 2022-04-19 13:17:23    979945         9                denim_blue         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 68   979945009    men_jeans_loose         loose_jeans          39.99 2022-04-19 13:17:23    979945         9                light_gray         NaN                     NaN          NaN         NaN   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%   Cotton 0%   Spandex 0%  Polyester 0%
# 69   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22                denim_blue  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 70   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22          light_denim_blue  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 71   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22          black_washed_out  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 72   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22                     white  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 73   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22              black_washed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 74   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22   dark_denim_blue_trashed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 75   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22             black_trashed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 76   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22         dark_blue_trashed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 77   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22      dark_blue_washed_out  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 78   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22        denim_blue_trashed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 79   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22                     black  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 80   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22                denim_gray  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 81   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22  light_denim_blue_trashed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 82   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22  light_denim_gray_trashed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 83   690449022   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        22                      gray  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 84   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36                denim_blue  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 85   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36          light_denim_blue  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 86   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36          black_washed_out  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 87   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36                     white  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 88   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36              black_washed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 89   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36   dark_denim_blue_trashed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 90   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36             black_trashed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 91   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36         dark_blue_trashed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 92   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36      dark_blue_washed_out  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 93   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36        denim_blue_trashed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 94   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36                     black  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 95   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36                denim_gray  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 96   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36  light_denim_blue_trashed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 97   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36  light_denim_gray_trashed  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 98   690449036   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        36                      gray  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%
# 99   690449051   men_jeans_ripped        skinny_jeans          39.99 2022-04-19 13:17:23    690449        51                denim_blue  skinny_fit  Cotton 98%, Spandex 2%        187.0  size 32/32  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%  Cotton 98%   Spandex 2%  Polyester 0%

# %%
#format composition data
data['cotton'] = data['cotton'].apply( lambda x: int( re.search( '\d+', x ).group(0) ) /100 if pd.notnull( x ) else x )
data['spandex'] = data['spandex'].apply( lambda x: int( re.search( '\d+', x ).group(0) ) /100 if pd.notnull( x ) else x )
data['elastomultiester'] = data['elastomultiester'].apply( lambda x: int( re.search( '\d+', x).group(0) ) /100 if pd.notnull( x ) else x )

# %%
#Cleaning dataframe
data = data.dropna( subset=['product_id'] )
data['product_id'] = data['product_id'].astype( int )

# %%
data.isna().sum()
# Out:
# product_id            0
# product_category      0
# product_name          0
# product_price         0
# scrapy_datetime       0
# style_id              0
# color_id              0
# color_name            1
# fit                 393
# composition         393
# size_number         393
# size_model          393
# cotton                0
# spandex               0
# polyester             0
# cotton                0
# spandex               0
# polyester             0
# cotton                0
# spandex               0
# polyester             0
# dtype: int64

# %%
data.head()
# Out:
#      product_id product_category product_name  product_price     scrapy_datetime   style_id  color_id        color_name       fit                    composition  size_number  size_model  cotton  spandex  elastomultiester
# 0  1.024256e+09   men_jeans_slim   slim_jeans          19.99 2022-04-18 17:54:04  1024256.0       1.0  light_denim_blue  slim_fit  Shell: Cotton 99%, Spandex 1%        185.0  size 31/32    0.99     0.01               NaN
# 2  1.024256e+09   men_jeans_slim   slim_jeans          19.99 2022-04-18 17:54:04  1024256.0       1.0  light_denim_blue  slim_fit  Shell: Cotton 99%, Spandex 1%        185.0  size 31/32    0.99     0.01               NaN
# 4  1.024256e+09   men_jeans_slim   slim_jeans          19.99 2022-04-18 17:54:04  1024256.0       1.0        denim_blue  slim_fit  Shell: Cotton 99%, Spandex 1%        185.0  size 31/32    0.99     0.01               NaN
# 6  1.024256e+09   men_jeans_slim   slim_jeans          19.99 2022-04-18 17:54:04  1024256.0       1.0         dark_blue  slim_fit  Shell: Cotton 99%, Spandex 1%        185.0  size 31/32    0.99     0.01               NaN
# 8  1.024256e+09   men_jeans_slim   slim_jeans          19.99 2022-04-18 17:54:04  1024256.0       1.0   dark_denim_blue  slim_fit  Shell: Cotton 99%, Spandex 1%        185.0  size 31/32    0.99     0.01               NaN

# %%
Continuar no proximo ciclo!
# Out:
#   Input In [23]
#     Continuar no proximo ciclo!
#               ^
# SyntaxError: invalid syntax

# %%
#save to datafrmae pre-cleaned
data.to_csv('../data/data_raw_clean.csv')

# %%
COLEtar os dados novamente!
